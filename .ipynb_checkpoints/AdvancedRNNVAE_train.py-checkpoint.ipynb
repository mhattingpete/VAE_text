# %% [markdown]
# # Train script for Advanced RNN VAE model

# %% [markdown]
# ### imports

# %%
# %matplotlib inline

from torch.autograd import Variable
from torch import optim
from torch.utils.data import DataLoader
import torch
import matplotlib.pyplot as plt
import numpy as np

# local imports
from helpers import kl_loss,nll_loss,mse_loss
from visualize import showPlot,plotPredictions
from models import AdvancedRNNVAE
from ToyDatasets.timeSeries import Sinusoids

# %% [markdown]
# ## Define dataset loader

# %%
batch_size = 256
num_steps = 16
dataset_size = 20000
num_classes = 10

data_loader = DataLoader(Sinusoids(num_steps,virtual_size=dataset_size,quantization=num_classes),batch_size=batch_size,shuffle=True)
valid_data_loader = DataLoader(Sinusoids(num_steps,virtual_size=dataset_size,quantization=num_classes),batch_size=batch_size,shuffle=True)

batch_loader = iter(data_loader)
valid_batch_loader = iter(valid_data_loader)

# %% [markdown]
# ## Define model

# %%
model = AdvancedRNNVAE(input_size=1,rnn_size=256,latent_size=32,output_size=num_classes,use_softmax=True,bidirectional=False)
print("Number of trainable parameters {}".format(sum(p.numel() for p in model.parameters() if p.requires_grad)))

# test forward pass
try:
    initial_batch = batch_loader.next()
    x = Variable(initial_batch).type(torch.FloatTensor).transpose(1,0)
    test,_ = model(x)
    assert (test.shape[0] == x.shape[0] and test.shape[1] == x.shape[1])
    print("Forward pass succesfull")
except:
    print("Error in forward pass. Output should have shape: {} but had {}".format(x.contiguous().view(-1).shape,test.view(-1).shape))
# Out:
# Number of trainable parameters 621898
# Forward pass succesfull

# %% [markdown]
# ## Define optimizer and loss

# %%
learning_rate = 1e-4
optimizer = optim.Adam(model.parameters(),lr=learning_rate)

# %% [markdown]
# ## Define trainer

# %%
def train(batch_loader,valid_batch_loader,model,optimizer,loss_fn,n_iters=1000,use_softmax=False,print_every=100):
    train_data = {"x":[],"recon_x":[]}
    valid_data = {"x":[],"recon_x":[]}
    plot_losses = []
    plot_losses_valid = []
    beta_start_inc = int(n_iters*0.4)
    beta_weight = 5e-4
    beta_max = 0.1
    beta_inc = 2e-6
    # start training and evaluating
    for i in range(1,n_iters+1):
        if i > beta_start_inc and beta_weight < beta_max:
            beta_weight += beta_inc
        # train
        try:
            batch = next(batch_loader)
        except StopIteration:
            batch_loader = iter(data_loader)
            batch = next(batch_loader)
        x = Variable(batch).type(torch.FloatTensor).transpose(1,0)
        model.train()
        optimizer.zero_grad()
        recon_x,qz = model(x)
        train_data["x"] = x.squeeze(2)
        if use_softmax:
            _,topi = recon_x.squeeze(2).data.topk(1)
            train_data["recon_x"] = Variable(topi)
        else:
            train_data["recon_x"] = recon_x.squeeze(2)
        r_loss = loss_fn(recon_x,x)
        kl = kl_loss(qz)
        loss = r_loss + beta_weight * kl
        loss.backward()
        optimizer.step()
        if i % print_every == 0:
            plot_losses.append(loss.data[0])
            print('\nTrain ({0:d} {1:d}%) loss: {2:.4f} r_loss: {3:.4f} kl: {4:.4f}'.format(i,int(i/n_iters*100),loss.data[0],r_loss.data[0],kl.data[0]))
        # eval
        try:
            batch = next(valid_batch_loader)
        except StopIteration:
            valid_batch_loader = iter(valid_data_loader)
            batch = next(valid_batch_loader)
        x = Variable(batch).type(torch.FloatTensor).transpose(1,0)
        model.eval()
        recon_x,qz = model(x)
        valid_data["x"] = x.squeeze(2)
        if use_softmax:
            _,topi = recon_x.squeeze(2).data.topk(1)
            valid_data["recon_x"] = Variable(topi)
        else:
            valid_data["recon_x"] = recon_x.squeeze(2)
        r_loss = loss_fn(recon_x,x)
        kl = kl_loss(qz)
        loss = r_loss + beta_weight * kl
        if i % print_every == 0:
            plot_losses_valid.append(loss.data[0])
            print('Valid ({0:d} {1:d}%) loss: {2:.4f} r_loss: {3:.4f} kl: {4:.4f}'.format(i,int(i/n_iters*100),loss.data[0],r_loss.data[0],kl.data[0]))
    if use_softmax:
        num_classes = recon_x.shape[2]
        showPlot(plot_losses,plot_losses_valid,yu=2.5)
        plotPredictions(train_data['x'],train_data['recon_x'],xu=num_steps,yu=num_classes)
        plotPredictions(valid_data['x'],valid_data['recon_x'],xu=num_steps,yu=num_classes)
    else:
        showPlot(plot_losses,plot_losses_valid,yu=0.5)
        plotPredictions(train_data['x'],train_data['recon_x'],xu=num_steps,yu=1)
        plotPredictions(valid_data['x'],valid_data['recon_x'],xu=num_steps,yu=1)

# %%
# use at least 1000 iterations to get good results
train(batch_loader,valid_batch_loader,model,optimizer,nll_loss,n_iters=1000,use_softmax=True,print_every=100)
# Out:
# Train (100 10%) loss: 1.5747 r_loss: 1.5732 kl: 2.9328
# Valid (100 10%) loss: 1.5521 r_loss: 1.5507 kl: 2.6209
#
# Train (200 20%) loss: 0.9656 r_loss: 0.9577 kl: 15.6504
# Valid (200 20%) loss: 0.9714 r_loss: 0.9636 kl: 15.5860
#
# Train (300 30%) loss: 0.5763 r_loss: 0.5588 kl: 35.1008
# Valid (300 30%) loss: 0.5736 r_loss: 0.5563 kl: 34.4819
#
# Train (400 40%) loss: 0.3651 r_loss: 0.3412 kl: 47.9303
# Valid (400 40%) loss: 0.3725 r_loss: 0.3488 kl: 47.3609
#
# Train (500 50%) loss: 0.2458 r_loss: 0.2062 kl: 56.5095
# Valid (500 50%) loss: 0.2427 r_loss: 0.2037 kl: 55.6153
#
# Train (600 60%) loss: 0.1894 r_loss: 0.1358 kl: 59.5769
# Valid (600 60%) loss: 0.1803 r_loss: 0.1279 kl: 58.2946
#
# Train (700 70%) loss: 0.1580 r_loss: 0.0947 kl: 57.6116
# Valid (700 70%) loss: 0.1667 r_loss: 0.1023 kl: 58.5738
#
# Train (800 80%) loss: 0.1531 r_loss: 0.0846 kl: 52.7226
# Valid (800 80%) loss: 0.1535 r_loss: 0.0836 kl: 53.7799
#
# Train (900 90%) loss: 0.1454 r_loss: 0.0750 kl: 46.9867
# Valid (900 90%) loss: 0.1526 r_loss: 0.0820 kl: 47.0780
#
# Train (1000 100%) loss: 0.1465 r_loss: 0.0739 kl: 42.6834
# Valid (1000 100%) loss: 0.1416 r_loss: 0.0689 kl: 42.7689

# %%
#torch.save(model.state_dict(),"Saved_models/RNNVAE.pt")
