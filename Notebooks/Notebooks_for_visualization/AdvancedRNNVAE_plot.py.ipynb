# %% [markdown]
# # Plot script for Advanced RNN VAE model

# %% [markdown]
# ### imports

# %%
# %matplotlib inline

from torch.autograd import Variable
import torch

import sys
sys.path.append("../../Modules")

# local imports
from models import AdvancedRNNVAE
from dot import make_dot,make_dot_from_trace

# %% [markdown]
# ## Define input and model

# %%
model = AdvancedRNNVAE(input_size=1,rnn_size=8,latent_size=2,output_size=5,use_softmax=True)

x = Variable(torch.randn(16,1,1))

# %% [markdown]
# ## Plot model

# %%
make_dot(model(x)[0],params=dict(model.named_parameters()))
