# %% [markdown]
# # Plot script for Ladder CNN VAE model

# %% [markdown]
# ### imports

# %%
# %matplotlib inline

from torch.autograd import Variable
import torch

import sys
sys.path.append("../../Modules")

# local imports
from models import LadderCNNVAE
from dot import make_dot,make_dot_from_trace

# %% [markdown]
# ## Define input and model

# %%
model = LadderCNNVAE(input_size=1,hidden_sizes=[16,8,4],latent_sizes=[8,4,2],recon_hidden_size=8,output_size=5,use_softmax=True)

x = Variable(torch.randn(16,1,1))

# %% [markdown]
# ## Plot model

# %%
make_dot(model(x)[0],params=dict(model.named_parameters()))
