# %% [markdown]
# # Train script for Advanced Hybrid VAE model

# %% [markdown]
# ### imports

# %%
# %matplotlib inline

from torch.autograd import Variable
import torch

import sys
sys.path.append("../../Modules")

# local imports
from models import AdvancedHybridVAE
from dot import make_dot,make_dot_from_trace

# %% [markdown]
# ## Define input and model

# %%
model = AdvancedHybridVAE(input_size=1,conv_size=8,rnn_size=8,latent_size=2,output_size=5,use_softmax=True)

x = Variable(torch.randn(16,1,1))

# %% [markdown]
# ## Plot model

# %%
make_dot(model(x)[0],params=dict(model.named_parameters()))
